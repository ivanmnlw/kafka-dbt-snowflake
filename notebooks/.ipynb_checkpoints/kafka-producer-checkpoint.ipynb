# %%
import json
import uuid
import os
import json
import random
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaProducer
from faker import Faker
from time import sleep

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')
kafka_topic = os.getenv('KAFKA_TOPIC_NAME')
kafka_topic_partition = os.getenv('KAFKA_TOPIC_NAME')+"-1"

# %%
print(kafka_topic)
# Out:
# test-topic

# %%
producer = KafkaProducer(bootstrap_servers=f'{kafka_host}:9092')

# %%
faker = Faker()

# %%
print(round(random.uniform(1.5, 5.7), 2))
# Out:
# 4.42

# %%
def get_data():
    return [
            uuid.uuid4().__str__(), # trip_id
            faker.random_element(elements=('app', 'website', 'offline')), # booking_source
            faker.date_time().strftime("%Y-%m-%d %H:%M:%S"), # booking_timestamp
            faker.random_int(min=1, max=100), # destination_location
            faker.random_int(min=1, max=1000), # driver_id
            float(faker.latitude()), # drivers_current_lat
            float(faker.longitude()), # drivers_current_lon
            faker.random_int(min=1, max=100), # drivers_location
            faker.random_int(min=1, max=5), # drivers_review
            faker.random_int(min=1, max=10), # estimated_arrival_time_in_m
            faker.random_int(min=15000, max=100000), # estimated_fare
            faker.random_int(min=1, max=5), # number_of_passenger
            faker.date_time().strftime("%Y-%m-%d %H:%M:%S"), # order_completion_time
            float(faker.latitude()), # passenger_arrival_lat
            float(faker.longitude()), # passenger_arrival_lon
            float(faker.latitude()), # passenger_current_lat
            float(faker.longitude()), # passenger_current_lon
            faker.date_time().strftime("%Y-%m-%d %H:%M:%S"), # passenger_pick_up_time
            faker.random_int(min=1, max=100), # pickup_location
            faker.random_element(elements=('completed', 'accepted', 'cancelled')), # status
            faker.random_int(min=1, max=100), # taxi_id
            faker.random_element(elements=('morning', 'afternoon', 'night')), # time_of_day
            faker.random_element(elements=('light', 'heavy')), # traffic_condition
            round(random.uniform(1.5, 10.7), 2), # trip_distance
            round(random.uniform(1.5, 10.7), 2), # trip_duration
            faker.random_int(min=1, max=5), # trip_rating
            uuid.uuid4().__str__(), # user_id
            faker.random_element(elements=('rainy', 'sunny', 'cloudy')) # weather_condition
    ]

# %%
for i in range(5):
    columns = ["trip_id", "booking_source", "booking_timestamp", "destination_location", "driver_id", "drivers_current_lat", 
               "drivers_current_lon", "drivers_location", "drivers_review", "estimated_arrival_time_in_m", "estimated_fare",
               "number_of_passenger", "order_completion_time", "passenger_arrival_lat", "passenger_arrival_lon", "passenger_current_lat",
               "passenger_current_lon", "passenger_pick_up_time", "pickup_location", "status", "taxi_id", "time_of_day", 
               "traffic_condition", "trip_distance", "trip_duration", "trip_rating", "user_id", "weather_condition"
              ]
    data_list = get_data()
    json_data = dict(zip(columns, data_list))
    _payload = json.dumps(json_data).encode("utf-8")
    response = producer.send(topic=kafka_topic, value=_payload)
    print(_payload)
# Out:
# b'{"trip_id": "cf91ee4d-8faf-463b-8e08-7881a75b5dc7", "booking_source": "app", "booking_timestamp": "2001-09-17 19:22:13", "destination_location": 66, "driver_id": 874, "drivers_current_lat": 49.6201525, "drivers_current_lon": 162.629006, "drivers_location": 36, "drivers_review": 4, "estimated_arrival_time_in_m": 2, "estimated_fare": 25840, "number_of_passenger": 4, "order_completion_time": "1977-11-08 09:50:41", "passenger_arrival_lat": -41.0392355, "passenger_arrival_lon": 5.721478, "passenger_current_lat": -76.414404, "passenger_current_lon": -36.806576, "passenger_pick_up_time": "2002-08-12 07:05:25", "pickup_location": 97, "status": "cancelled", "taxi_id": 12, "time_of_day": "afternoon", "traffic_condition": "light", "trip_distance": 6.98, "trip_duration": 6.43, "trip_rating": 4, "user_id": "dc8df7cc-a170-419d-8d83-eb5c5eee7b2a", "weather_condition": "rainy"}'
# b'{"trip_id": "3addb10e-8480-4fe5-a695-416c9102b1f7", "booking_source": "website", "booking_timestamp": "2002-11-10 08:16:13", "destination_location": 45, "driver_id": 353, "drivers_current_lat": 19.453996, "drivers_current_lon": -148.494133, "drivers_location": 17, "drivers_review": 1, "estimated_arrival_time_in_m": 8, "estimated_fare": 67917, "number_of_passenger": 4, "order_completion_time": "1998-11-04 08:01:13", "passenger_arrival_lat": -53.729558, "passenger_arrival_lon": 22.012558, "passenger_current_lat": -57.601687, "passenger_current_lon": -13.386262, "passenger_pick_up_time": "1995-04-05 18:57:08", "pickup_location": 93, "status": "cancelled", "taxi_id": 25, "time_of_day": "afternoon", "traffic_condition": "heavy", "trip_distance": 6.0, "trip_duration": 5.09, "trip_rating": 5, "user_id": "006e4125-dabe-4252-8df9-9eca90369e4e", "weather_condition": "rainy"}'
# b'{"trip_id": "d576fb70-45b5-420c-933b-470ea0f64c76", "booking_source": "website", "booking_timestamp": "2016-06-21 16:56:31", "destination_location": 23, "driver_id": 582, "drivers_current_lat": 38.9779795, "drivers_current_lon": 153.07596, "drivers_location": 39, "drivers_review": 2, "estimated_arrival_time_in_m": 4, "estimated_fare": 47552, "number_of_passenger": 5, "order_completion_time": "2024-08-22 19:53:43", "passenger_arrival_lat": -33.543232, "passenger_arrival_lon": -82.810385, "passenger_current_lat": -2.55838, "passenger_current_lon": -151.613973, "passenger_pick_up_time": "2021-02-13 16:10:32", "pickup_location": 69, "status": "cancelled", "taxi_id": 68, "time_of_day": "morning", "traffic_condition": "light", "trip_distance": 6.56, "trip_duration": 2.42, "trip_rating": 2, "user_id": "6fef28b5-bb99-40a7-a180-192ade81298d", "weather_condition": "rainy"}'
# b'{"trip_id": "d7e13ed8-9e51-4dee-8eba-d6edc4bf24d0", "booking_source": "offline", "booking_timestamp": "2013-12-30 02:28:15", "destination_location": 36, "driver_id": 29, "drivers_current_lat": -5.3576795, "drivers_current_lon": -65.834877, "drivers_location": 74, "drivers_review": 5, "estimated_arrival_time_in_m": 10, "estimated_fare": 76975, "number_of_passenger": 5, "order_completion_time": "1983-12-23 18:24:57", "passenger_arrival_lat": 8.235746, "passenger_arrival_lon": -5.659827, "passenger_current_lat": -56.570653, "passenger_current_lon": 78.996021, "passenger_pick_up_time": "1992-07-08 04:13:24", "pickup_location": 22, "status": "accepted", "taxi_id": 73, "time_of_day": "morning", "traffic_condition": "heavy", "trip_distance": 10.51, "trip_duration": 10.6, "trip_rating": 3, "user_id": "991f24d2-afff-456a-8895-32702cbbae76", "weather_condition": "cloudy"}'
# b'{"trip_id": "f88417d9-4e63-4e0b-888c-94c0167d8cea", "booking_source": "app", "booking_timestamp": "2016-04-17 10:40:47", "destination_location": 39, "driver_id": 36, "drivers_current_lat": 50.1422085, "drivers_current_lon": 49.290993, "drivers_location": 33, "drivers_review": 4, "estimated_arrival_time_in_m": 9, "estimated_fare": 45951, "number_of_passenger": 1, "order_completion_time": "1994-11-16 02:20:06", "passenger_arrival_lat": -5.657266, "passenger_arrival_lon": 97.349133, "passenger_current_lat": -24.9017475, "passenger_current_lon": -130.135623, "passenger_pick_up_time": "2021-08-23 00:36:17", "pickup_location": 29, "status": "completed", "taxi_id": 28, "time_of_day": "morning", "traffic_condition": "heavy", "trip_distance": 9.87, "trip_duration": 3.25, "trip_rating": 2, "user_id": "18724b59-e829-4818-bf60-0d834edf2815", "weather_condition": "rainy"}'
