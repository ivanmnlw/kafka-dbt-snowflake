# %%
import json
import uuid
import os
import json
import random
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaProducer
from faker import Faker
from time import sleep

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')
kafka_topic = os.getenv('KAFKA_TOPIC_NAME')
kafka_topic_partition = os.getenv('KAFKA_TOPIC_NAME')+"-1"

# %%
print(kafka_topic)
# Out:
# test-topic

# %%
from kafka import KafkaConsumer

# To consume latest messages and auto-commit offsets
consumer = KafkaConsumer(kafka_topic,
                         group_id='dbt-snowflake-group',
                         bootstrap_servers=[f'{kafka_host}:9092'],
                         auto_offset_reset='earliest',value_deserializer=lambda x: json.loads(x.decode('utf-8')))

# %%
for message in consumer:
    print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                          message.offset, message.key,
                                          message.value))
# Out:
# test-topic:0:45: key=None value={'trip_id': '7a37edf5-e1dc-4f39-955b-2032b8d709f1', 'booking_source': 'offline', 'booking_timestamp': '1997-05-25 09:21:45', 'destination_location': 23, 'driver_id': 392, 'drivers_current_lat': 2.367925, 'drivers_current_lon': -34.281932, 'drivers_location': 97, 'drivers_review': 4, 'estimated_arrival_time_in_m': 6, 'estimated_fare': 45033, 'number_of_passenger': 4, 'order_completion_time': '1976-01-15 03:36:15', 'passenger_arrival_lat': -83.7397865, 'passenger_arrival_lon': 31.582019, 'passenger_current_lat': 23.3814775, 'passenger_current_lon': 113.254401, 'passenger_pick_up_time': '1976-09-30 07:34:37', 'pickup_location': 70, 'status': 'cancelled', 'taxi_id': 99, 'time_of_day': 'morning', 'traffic_condition': 'light', 'trip_distance': 5.02, 'trip_duration': 1.95, 'trip_rating': 5, 'user_id': '4c9025e5-4a88-4734-a42e-148adb08f88d', 'weather_condition': 'rainy'}
# test-topic:0:46: key=None value={'trip_id': '117c88db-e6f1-4133-b4ae-8f2e79fb20a3', 'booking_source': 'website', 'booking_timestamp': '1998-08-01 17:16:20', 'destination_location': 77, 'driver_id': 558, 'drivers_current_lat': 7.9460855, 'drivers_current_lon': 41.581309, 'drivers_location': 52, 'drivers_review': 4, 'estimated_arrival_time_in_m': 10, 'estimated_fare': 40856, 'number_of_passenger': 2, 'order_completion_time': '1970-04-12 02:09:50', 'passenger_arrival_lat': -34.209052, 'passenger_arrival_lon': -37.502821, 'passenger_current_lat': 58.9150975, 'passenger_current_lon': 135.694778, 'passenger_pick_up_time': '1994-07-06 05:54:41', 'pickup_location': 60, 'status': 'accepted', 'taxi_id': 35, 'time_of_day': 'afternoon', 'traffic_condition': 'heavy', 'trip_distance': 9.27, 'trip_duration': 8.31, 'trip_rating': 2, 'user_id': '36e11e74-33b3-4b75-a585-20d61c606920', 'weather_condition': 'rainy'}
# test-topic:0:47: key=None value={'trip_id': 'c03a881a-3ee6-422c-a836-61ed722fe00d', 'booking_source': 'offline', 'booking_timestamp': '1987-01-29 15:16:40', 'destination_location': 5, 'driver_id': 349, 'drivers_current_lat': 77.0395705, 'drivers_current_lon': 64.987773, 'drivers_location': 44, 'drivers_review': 3, 'estimated_arrival_time_in_m': 2, 'estimated_fare': 98658, 'number_of_passenger': 3, 'order_completion_time': '1975-12-09 20:37:12', 'passenger_arrival_lat': -18.698411, 'passenger_arrival_lon': -178.953592, 'passenger_current_lat': -80.465204, 'passenger_current_lon': 142.681309, 'passenger_pick_up_time': '1999-04-08 17:21:35', 'pickup_location': 69, 'status': 'completed', 'taxi_id': 20, 'time_of_day': 'morning', 'traffic_condition': 'heavy', 'trip_distance': 6.1, 'trip_duration': 2.0, 'trip_rating': 2, 'user_id': '30df396d-8e9c-41e2-adde-8d095f6fe12b', 'weather_condition': 'sunny'}
# test-topic:0:48: key=None value={'trip_id': 'd2e659ed-2204-4c0b-86cc-12b6bafb7609', 'booking_source': 'app', 'booking_timestamp': '1992-08-20 02:23:20', 'destination_location': 11, 'driver_id': 858, 'drivers_current_lat': 5.4853665, 'drivers_current_lon': -61.919868, 'drivers_location': 18, 'drivers_review': 1, 'estimated_arrival_time_in_m': 6, 'estimated_fare': 76071, 'number_of_passenger': 4, 'order_completion_time': '1997-12-04 01:49:02', 'passenger_arrival_lat': 68.383122, 'passenger_arrival_lon': -39.84259, 'passenger_current_lat': -69.154834, 'passenger_current_lon': -93.680708, 'passenger_pick_up_time': '2004-11-28 04:18:36', 'pickup_location': 23, 'status': 'cancelled', 'taxi_id': 5, 'time_of_day': 'afternoon', 'traffic_condition': 'light', 'trip_distance': 8.7, 'trip_duration': 9.71, 'trip_rating': 1, 'user_id': 'ca10af15-71de-45ab-937f-889b47aa4e7d', 'weather_condition': 'rainy'}
# test-topic:0:49: key=None value={'trip_id': '9e268cb0-cf64-4f52-a70e-a5fea3f058c9', 'booking_source': 'offline', 'booking_timestamp': '2017-05-18 18:07:28', 'destination_location': 49, 'driver_id': 127, 'drivers_current_lat': 86.2243365, 'drivers_current_lon': 117.696239, 'drivers_location': 77, 'drivers_review': 4, 'estimated_arrival_time_in_m': 10, 'estimated_fare': 20302, 'number_of_passenger': 2, 'order_completion_time': '2016-04-10 21:53:02', 'passenger_arrival_lat': -15.372878, 'passenger_arrival_lon': 102.512524, 'passenger_current_lat': -39.2578545, 'passenger_current_lon': 43.195641, 'passenger_pick_up_time': '1989-03-14 20:23:22', 'pickup_location': 31, 'status': 'cancelled', 'taxi_id': 74, 'time_of_day': 'afternoon', 'traffic_condition': 'heavy', 'trip_distance': 10.03, 'trip_duration': 9.49, 'trip_rating': 2, 'user_id': 'a4dafcf5-6e29-43e3-9497-7056e4ffc866', 'weather_condition': 'sunny'}
# test-topic:0:50: key=None value={'trip_id': '9ab2fb93-327b-4ea6-a61e-3b6c900966c6', 'booking_source': 'offline', 'booking_timestamp': '1993-02-16 12:49:09', 'destination_location': 66, 'driver_id': 962, 'drivers_current_lat': 66.339086, 'drivers_current_lon': 59.886083, 'drivers_location': 60, 'drivers_review': 4, 'estimated_arrival_time_in_m': 2, 'estimated_fare': 17816, 'number_of_passenger': 1, 'order_completion_time': '1983-08-11 05:51:20', 'passenger_arrival_lat': 13.871548, 'passenger_arrival_lon': 44.165202, 'passenger_current_lat': 22.7291935, 'passenger_current_lon': 84.671271, 'passenger_pick_up_time': '1978-12-13 07:31:27', 'pickup_location': 39, 'status': 'cancelled', 'taxi_id': 82, 'time_of_day': 'morning', 'traffic_condition': 'light', 'trip_distance': 10.44, 'trip_duration': 1.56, 'trip_rating': 3, 'user_id': '392eb7aa-c459-4fed-b238-7e69cd376eba', 'weather_condition': 'cloudy'}
# test-topic:0:51: key=None value={'trip_id': '058a4ce0-77e6-441d-81be-b702ab3a19d1', 'booking_source': 'offline', 'booking_timestamp': '2007-12-16 09:02:07', 'destination_location': 3, 'driver_id': 612, 'drivers_current_lat': 20.4407615, 'drivers_current_lon': -176.685168, 'drivers_location': 57, 'drivers_review': 5, 'estimated_arrival_time_in_m': 5, 'estimated_fare': 84543, 'number_of_passenger': 5, 'order_completion_time': '2017-04-19 03:55:08', 'passenger_arrival_lat': -6.918857, 'passenger_arrival_lon': -48.877187, 'passenger_current_lat': 79.4578955, 'passenger_current_lon': 91.816148, 'passenger_pick_up_time': '1985-06-25 09:59:16', 'pickup_location': 36, 'status': 'cancelled', 'taxi_id': 59, 'time_of_day': 'night', 'traffic_condition': 'light', 'trip_distance': 4.5, 'trip_duration': 6.71, 'trip_rating': 5, 'user_id': 'eaa47888-0863-4726-ba0b-87d37ee374bf', 'weather_condition': 'sunny'}
# test-topic:0:52: key=None value={'trip_id': '415933e4-9799-43d7-8523-8827477840d0', 'booking_source': 'app', 'booking_timestamp': '2000-12-05 00:37:52', 'destination_location': 71, 'driver_id': 215, 'drivers_current_lat': -40.457678, 'drivers_current_lon': -117.156165, 'drivers_location': 99, 'drivers_review': 5, 'estimated_arrival_time_in_m': 10, 'estimated_fare': 77631, 'number_of_passenger': 5, 'order_completion_time': '1998-12-21 06:16:00', 'passenger_arrival_lat': -85.72621, 'passenger_arrival_lon': -118.844824, 'passenger_current_lat': -30.617424, 'passenger_current_lon': -55.747771, 'passenger_pick_up_time': '2019-04-03 03:32:40', 'pickup_location': 31, 'status': 'cancelled', 'taxi_id': 70, 'time_of_day': 'morning', 'traffic_condition': 'light', 'trip_distance': 7.29, 'trip_duration': 8.18, 'trip_rating': 5, 'user_id': '4506f52c-985c-4453-b43c-ae2d4e9c6127', 'weather_condition': 'rainy'}
# test-topic:0:53: key=None value={'trip_id': '11f535bc-4eea-48e8-bc97-fa774630ffed', 'booking_source': 'offline', 'booking_timestamp': '2012-02-13 16:17:44', 'destination_location': 80, 'driver_id': 539, 'drivers_current_lat': 84.018237, 'drivers_current_lon': 43.668391, 'drivers_location': 36, 'drivers_review': 1, 'estimated_arrival_time_in_m': 10, 'estimated_fare': 34434, 'number_of_passenger': 2, 'order_completion_time': '1974-08-06 18:03:48', 'passenger_arrival_lat': -18.3403825, 'passenger_arrival_lon': 152.269383, 'passenger_current_lat': -87.504595, 'passenger_current_lon': 127.101554, 'passenger_pick_up_time': '1991-04-24 02:29:48', 'pickup_location': 4, 'status': 'accepted', 'taxi_id': 54, 'time_of_day': 'night', 'traffic_condition': 'heavy', 'trip_distance': 9.01, 'trip_duration': 3.92, 'trip_rating': 2, 'user_id': '61c8202a-cf7d-49ce-be46-67fe89935913', 'weather_condition': 'rainy'}
# test-topic:0:54: key=None value={'trip_id': 'd9989b5f-7147-4577-8780-f859cca04ec3', 'booking_source': 'app', 'booking_timestamp': '2017-11-09 09:06:35', 'destination_location': 50, 'driver_id': 743, 'drivers_current_lat': 9.097816, 'drivers_current_lon': -77.484792, 'drivers_location': 38, 'drivers_review': 3, 'estimated_arrival_time_in_m': 8, 'estimated_fare': 93313, 'number_of_passenger': 2, 'order_completion_time': '1979-07-01 17:44:42', 'passenger_arrival_lat': 9.67903, 'passenger_arrival_lon': -94.110646, 'passenger_current_lat': -75.872019, 'passenger_current_lon': 120.642878, 'passenger_pick_up_time': '2009-08-16 12:59:37', 'pickup_location': 36, 'status': 'completed', 'taxi_id': 90, 'time_of_day': 'afternoon', 'traffic_condition': 'heavy', 'trip_distance': 9.18, 'trip_duration': 5.29, 'trip_rating': 3, 'user_id': '9b914c1a-bef5-4ffd-8250-ca5de5afd755', 'weather_condition': 'rainy'}
# test-topic:0:55: key=None value={'trip_id': '99ded21b-5ca5-48e3-a0ec-d3d1cc7617d8', 'booking_source': 'website', 'booking_timestamp': '1980-12-23 00:23:31', 'destination_location': 40, 'driver_id': 196, 'drivers_current_lat': 39.9527115, 'drivers_current_lon': -128.768566, 'drivers_location': 59, 'drivers_review': 2, 'estimated_arrival_time_in_m': 5, 'estimated_fare': 41129, 'number_of_passenger': 3, 'order_completion_time': '1983-05-26 22:06:38', 'passenger_arrival_lat': 79.0252035, 'passenger_arrival_lon': 5.568044, 'passenger_current_lat': 82.4929095, 'passenger_current_lon': 175.015663, 'passenger_pick_up_time': '1974-01-24 19:02:19', 'pickup_location': 30, 'status': 'accepted', 'taxi_id': 48, 'time_of_day': 'morning', 'traffic_condition': 'light', 'trip_distance': 9.03, 'trip_duration': 2.09, 'trip_rating': 5, 'user_id': 'b05aa778-6c88-4648-be50-2d684ef64afd', 'weather_condition': 'sunny'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for message in consumer:
#       2     print ("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
#       3                                           message.offset, message.key,
#       4                                           message.value))
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
